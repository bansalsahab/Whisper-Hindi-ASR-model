# %%
! pip install git+https://github.com/openai/whisper.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.3 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
import whisper

model = whisper.load_model("small")

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
from IPython.display import Audio
Audio("/content/01-04397-02.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
Audio("/content/02-19136-01.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# load audio
audio = whisper.load_audio("/content/02-19136-01.mp3")
audio = whisper.pad_or_trim(audio)
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# detect language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# audio decode
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

print(result.text)
# Out:
# Detected language: hi
# अदिकारों की मानितो तक्निकी बडलाव के कारन यह समच्या पैधा होई ती लेकिन अप समच्या लगबक दूर हो गया है यह अप खातिश ब्या जोडने काम तेजी सच्याज़ फिर भी लगबक तीसवी सदी सच्यो के प्रचाज़ लगब के लगब के लगब के लगब
